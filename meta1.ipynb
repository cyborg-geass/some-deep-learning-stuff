# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Cu-1.csv", encoding = "latin1")
df1 = pd.read_csv("MS-1.csv", encoding= "latin1")
df2 = pd.read_csv("FeAlSi-1.csv", encoding = "latin1")

# %%
df.shape
# Out:
# (23151, 5)

# %%
df.describe()
# Out:
#           Force (N)    Strain (%)  Stress (N/mmï¿½)    Time (sec)
# count  23150.000000  23150.000000      23150.000000  23150.000000
# mean    4347.313276     48.216803        153.759174    723.439254
# std     1222.360928     27.845539         43.232987    417.683388
# min     -743.000000      0.000000        -26.300000      0.000000
# 25%     3880.000000     24.100000        137.300000    362.000000
# 50%     4840.000000     48.200000        171.100000    723.000000
# 75%     5230.000000     72.300000        185.100000   1085.000000
# max     5320.000000     96.400000        188.000000   1447.000000

# %%
df.head(10)
# Out:
#   Position (mm)  Force (N)  Strain (%)  Stress (N/mmï¿½)  Time (sec)
# 0           0.0      0.000       0.000            0.0000      0.0000
# 1           0.0     -1.667       0.000           -0.0589      0.0625
# 2           0.0     -1.667       0.000           -0.0589      0.1719
# 3           0.0      0.000       0.000            0.0000      0.2340
# 4         0.001      6.670       0.004            0.2360      0.2970
# 5         0.002     20.000       0.008            0.7070      0.3590
# 6         0.003     36.700       0.012            1.2970      0.4220
# 7         0.004     58.300       0.016            2.0600      0.4840
# 8         0.006     81.700       0.024            2.8900      0.5470
# 9         0.007    100.000       0.028            3.5400      0.6090

# %%
df = df.iloc[2:,:]

# %%
df.head(10)
# Out:
#    Position (mm)  Force (N)  Strain (%)  Stress (N/mmï¿½)  Time (sec)
# 2            0.0     -1.667       0.000           -0.0589      0.1719
# 3            0.0      0.000       0.000            0.0000      0.2340
# 4          0.001      6.670       0.004            0.2360      0.2970
# 5          0.002     20.000       0.008            0.7070      0.3590
# 6          0.003     36.700       0.012            1.2970      0.4220
# 7          0.004     58.300       0.016            2.0600      0.4840
# 8          0.006     81.700       0.024            2.8900      0.5470
# 9          0.007    100.000       0.028            3.5400      0.6090
# 10         0.008    118.300       0.032            4.1900      0.6720
# 11         0.009    135.000       0.036            4.7700      0.7340

# %%
x = df['Strain (%)']
x1 = df1['Strain (%)']
x2 = df2['Strain (%)']

# %%
y = df['Stress (N/mmï¿½)']
y1 = df1['Stress (N/mmï¿½)']
y2 = df2['Stress (N/mmï¿½)']

# %%
plt.plot(x,y)
plt.plot(x1, y1)
plt.plot(x2, y2)
# plt.xlabel("Strain")
# plt.ylabel("Stress")
# plt.title("Cu-1")
